# %%
def some_func():
    print("hello world1")
    print("hello world2")
    print("hello world3")

# %%
some_func()
print('print after some func')
# Out:
# hello world1
# hello world2
# hello world3
# print after some func

# %%
my_list = [1, 2, 3]
print(id(my_list))
# Out:
# 134794776619200

# %%
my_list[0] = 10
print(my_list) # [10, 2, 3]
# Out:
# [10, 2, 3]

# %%
my_list.reverse() # функция, которая не возвращает перевернутый массив, а модифицирует существующий
my_list
# Out:
# [3, 2, 1]

# %%
my_list[::-1]
# Out:
# [1, 2, 3]

# %%
print(id(my_list))
# Out:
# 134794790326400

# %%
people = ["Tom", "Bob"]
people.append("Alice")

# %%
people
# Out:
# ['Tom', 'Bob', 'Alice']

# %%
mixed_list = [1, "two", 3.0, [4, 5]]
mixed_list
# Out:
# [1, 'two', 3.0, [4, 5]]

# %%
# методы
stringetto = 'Hello, World, Friend! My name is Freddo!'
greetings = 'Welcome on board, mr president.'
stringetto.split()
greetings.split()
# Out:
# ['Welcome', 'on', 'board,', 'mr', 'president.']

# %%
def do_nothing():
    pass

# %%
do_nothing(), do_nothing()
# Out:
# (None, None)

# %%
split_greetings = greetings.split()
split_greetings.sort()
split_greetings
# Out:
# ['Welcome', 'board,', 'mr', 'on', 'president.']

# %%
inputito = list(map(int, input().split()))
inputito
# Out:
# 1 2 3 4 5 6
# [1, 2, 3, 4, 5, 6]

# %%
split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b2c4ca1b6d28> in <cell line: 1>()
# ----> 1 split()
#
# NameError: name 'split' is not defined

# %%
some_list = [1, 2, 3]

# %%
some_list.append(4)

# %%
some_list
# Out:
# [1, 2, 3, 4]

# %%
some_list.extend([5, 6, 7, 8])
some_list
# Out:
# [1, 2, 3, 5, 6, 7, 8]

# %% [markdown]
# * Напишите программу, которая принимает список чисел от пользователя и выводит на экран только уникальные числа из списка в порядке их появления.
# * Используйте динамический массив для хранения уникальных чисел и методы для работы с ним. Выведите результат на экран с помощью команды print.
#
# * Пример вывода:
# * Введите числа, разделенные пробелами: 1 2 3 4 2 3 1 5
# * Уникальные числа: [1, 2, 3, 4, 5]

# %%
def выведи_принтом_только_уникальные_числа(неуникальный_массив):
    уникальный_массив = []

    # для каждого числа в неуникальном массиве
    for неуникальное_число in неуникальный_массив:
        # если этого числа    нет в уникальном_массиве
        if неуникальное_число not in уникальный_массив:
            # добавляем в уникальный_массив это (уникальное) число
            уникальный_массив.append(неуникальное_число)

    print(уникальный_массив)

# %%
неуникальный_массив = list(map(int, input('Введите числа, разделенные пробелами: ').split()))
# Out:
# Введите числа, разделенные пробелами: 7 5 9 3 4 8 7 1 3 5 9 2 10 15 4

# %%
неуникальный_массив
# Out:
# [7, 5, 9, 3, 4, 8, 7, 1, 3, 5, 9, 2, 10, 15, 4]

# %%
выведи_принтом_только_уникальные_числа(неуникальный_массив) # 7 5 9 3 4 8 1 2 10 15
# Out:
# [7, 5, 9, 3, 4, 8, 1, 2, 10, 15]
