# %%
my_list = [1, 2, 3, 4]
my_list.insert(2,5)  # Вставка числа 5 на позицию 2
my_list  # [1, 2, 5, 3, 4]
# Out:
# [1, 2, 5, 3, 4]

# %%
my_list = [1, 2, 3, 4, 2, 2]
my_list.remove(2) # удаление первой 2
print(my_list) # [1, 3, 4, 2, 2]
# Out:
# [1, 3, 4, 2, 2]

# %%
my_list.remove(2) # удаление первой 2
print(my_list) # [1, 3, 4, 2]
# Out:
# [1, 3, 4, 2]

# %%
my_list.remove(2) # удаление первой 2
print(my_list) # [1, 3, 4]
# Out:
# [1, 3, 4]

# %%
my_list.clear() # очищает массив от элементов
my_list
# Out:
# []

# %%
my_list = [1, 3, 4, 2, 7, 10, 12, 1, 4, 2, 10, 12, 12, 1, 3, 4, 7, 10, 12, 1, 4, 2, 10, 12, 12]
# len(my_list)
print(my_list.index(2, 4)) # индекс первой двойки - 3
# второй аргумент говорит нам о том, с какого индекса мы начинаем поиск
# по умолчанию, если ничего не передавать - то этот индекс 0
# Out:
# 9

# %%
my_list = [1, 2, 3, 4, 2, 2]
my_list.count(2) # подсчитывает кол-во повторений данного числа в списке
# Out:
# 3

# %%
# Что произойдет при выполнении этого фрагмента кода:

a = [66.25, 333, 333, 1, 1234.5]
a
# Out:
# [66.25, 333, 333, 1, 1234.5]

# %%
a.insert(2, -1)
a
