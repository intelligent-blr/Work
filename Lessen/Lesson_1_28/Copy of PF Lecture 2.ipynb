# %%
# ввод данных в программу - input
# вывод - print

# %%
# PRACTICE
int_var = 5
float_var = 5.0
str_var = '5'

type(int_var), type(float_var), type(str_var)
# Out:
# (int, float, str)

# %% [markdown]
# # **Выполнить перевод числа 24 из десятичной системы в двоичную, используя деление в столбик.**

# %%
# practice
bin(24)[2:], bin(24)
# [2:] - берём срез строки, начиная с третьего символа до конца
# Out:
# ('11000', '0b11000')

# %% [markdown]
# ## **Практическое задание**
#
# * Перевод чисел в двоичную систему:  5, -15, 259, -542, 7892
# * Перевод из двоичной системы в десятичную: 1010, 101111101, 101001010100101
# * Сложение чисел “столбиком”
# 1.   1010 + 101111101
# 2.   101111101 + 101001010100101
# * Проверка успешности сложения в десятичном формате!

# %%
# решаем сами
# int('11000', 2)
# bin(24)[2:]
# Out:
# (24, '11000')
