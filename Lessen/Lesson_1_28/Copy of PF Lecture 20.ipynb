# %%
my_set = {1, 2, 3}
my_frozen_set = frozenset({4, 5, 6})

my_set.add(4)  # Добавление элемента в изменяемое множество
my_frozen_set.add(7) # не можем изменить фрозенсет, он стал неизменяемым
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7f94009f757d> in <cell line: 0>()
#       3
#       4 my_set.add(4)  # Добавление элемента в изменяемое множество
# ----> 5 my_frozen_set.add(7)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
my_set = {x for x in range(5)}
my_set
# Out:
# {0, 1, 2, 3, 4}

# %%
my = [x for x in range(5)]
my
# Out:
# [0, 1, 2, 3, 4]

# %%
my_dict = {"name": "John", "age": 25, "city": "New York"}
my_dict
# Out:
# {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
my_dict['name']
# Out:
# 'John'

# %%
my_dict.items()
# Out:
# dict_items([('name', 'John'), ('age', 25), ('city', 'New York')])

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
my_dict.values()
# Out:
# dict_values(['John', 25, 'New York'])

# %%
for key in my_dict.keys():
    print(key)
# Out:
# name
# age
# city

# %%
for key, value in my_dict.items():
    print(key, value)
# Out:
# name John
# age 25
# city New York

# %%
my_dict['ruslan'] = 'ivanovichev'
my_dict
# Out:
# {'name': 'John', 'age': 25, 'city': 'New York', 'ruslan': 'ivanovichev'}

# %%
my_dict['ruslan'] = 'subbotin'
my_dict
# Out:
# {'name': 'John', 'age': 25, 'city': 'New York', 'ruslan': 'subbotin'}

# %%
my_dict = {"name": "John", "age": 25}
print("name" in my_dict)  # Выводит True
print("city" in my_dict)  # Выводит False
# Out:
# True
# False

# %%
del my_dict["age"]  # Удаление элемента по ключу
# my_dict.pop("city")  # Удаление элемента с возвратом значения

# %%
my_dict
# Out:
# {'name': 'John'}

# %%
my_dict = empty()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b67199ac4538> in <cell line: 0>()
# ----> 1 my_dict = empty()
#
# NameError: name 'empty' is not defined

# %%
my_dict = dict()
my_dict['add'] ='element'
my_dict
# Out:
# {'add': 'element'}

# %%
my_dict = {}
my_dict['add'] ='element'
my_dict
# Out:
# {'add': 'element'}

# %%
my_dict = []
my_dict
# Out:
# []

# %%
my_dict = ()

# %%
my_dict = set()

# %%
my_dict = dict{}
# Out:
#   File "<ipython-input-28-43abfaa3a99d>", line 1
#     my_dict = dict{}
#                   ^
# SyntaxError: invalid syntax

# %%
dictito = {'Canada': 'Ottawa', 'United States': 'Washington, D.C.', 'Mexico': 'Mexico City'}
dictito
# Out:
# {'Canada': 'Ottawa',
#  'United States': 'Washington, D.C.',
#  'Mexico': 'Mexico City'}

# %%
stuff = {1: 'ааа', 2: 'ббб', 3: 'ввв'}
print(stuff[3])
# Out:
# ввв
