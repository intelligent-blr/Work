# %% [markdown]
# ### **Импорт модулей**

# %%
import numpy

# %%
numpy.random.seed(42)

# %%
import numpy as np

# %%
np.random.seed(42)

# %%
from numpy import random as rd

# %%
rd.seed(42)

# %% [markdown]
# Функции в модуле math
#
# * sqrt() (квадратный корень)
# * sin() (синус)
# * cos() (косинус)
# * log() (логарифм)...

# %%
import math

print(math.sqrt(16))  # Выводит: 4.0
print(math.sin(math.pi/2))  # Выводит: 1.0
# Out:
# 4.0
# 1.0

# %%
from math import sqrt as псевдоним

# %%
псевдоним(16)
# Out:
# 4.0

# %%
math.exp(6) # 2.7 ^ 6
# Out:
# 403.4287934927351

# %%
math.pow(2.718, 6) # e - число Эйлера (2.7~~~)
# Out:
# 403.1778962208906

# %%
x = 4.1

math.ceil(x), math.floor(x)
# Out:
# (5, 4)

# %%
round(4.6) # округляет в ближайшую сторону
# Out:
# 5

# %%
math.pi, math.e
# Out:
# (3.141592653589793, 2.718281828459045)

# %%
math.fabs(-3), math.fabs(3)
# Out:
# (3.0, 3.0)

# %%
math.factorial(5)
# Out:
# 120

# %%
from math import factorial as ft

# %%
ft(5)
# Out:
# 120

# %% [markdown]
# Правильный многоугольник — выпуклый многоугольник, у которого равны все стороны и все углы между смежными сторонами. Площадь правильного многоугольника с длиной стороны a и количеством сторон n вычисляется по формуле:
#
#
#
# * Даны два числа: натуральное число n и вещественное число a. Напишите программу, которая находит площадь указанного правильного многоугольника.
# * Формат входных данных:
# * На вход программе подается два числа n и a, каждое на отдельной строке.
# * Формат выходных данных:
# * Программа должна вывести вещественное число – площадь многоугольника.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input('Введите кол-во сторон многоугольника: '))
a = int(input('Введите величину стороны многоугольника: '))
# Out:
# Введите кол-во сторон многоугольника: 3
# Введите величину стороны многоугольника: 5

# %%
import math

# %%
числитель = n * pow(a, 2)
знаменатель = 4 * math.tan(math.pi / n)
площадь = числитель / знаменатель

площадь
# Out:
# 10.825317547305486
