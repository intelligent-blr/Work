# %% [markdown]
# # РАЗБОР ДОМАШНЕГО ЗАДАНИЯ 27

# %% [markdown]
# ### Задание 1
#
# Напишите функцию, которая принимает на вход список чисел и возвращает сумму квадратов только четных чисел из списка, используя функциональные подходы (например, map, filter и reduce).
#
# Пример вывода:
#
# Введите числа: 4, 6, 3, 4, 2, 3, 9, 0, 7
#
# Результат: 72

# %%
from functools import reduce

def sq_sum(s):
    filt = filter(lambda x: x % 2 == 0, s)
    sqmap = map(lambda x: x * x, filt)
    sumsq = reduce(lambda x, y: x + y, sqmap)
    return sumsq

i = map(int, input("Введите список чисел: ").split(", "))
print(sq_sum(i))
# Out:
# Введите список чисел: 1, 2, 4, 5, 6
# 56

# %% [markdown]
# ### Задание 2
#
# Напишите функцию, которая принимает на вход список функций и значение, а затем применяет композицию этих функций к значению, возвращая конечный результат.
#
# Пример использования:
#
# add_one = lambda x: x + 1
#
# double = lambda x: x * 2
#
# subtract_three = lambda x: x - 3
#
# functions = [add_one, double, subtract_three]
#
# compose_functions(functions, 5) должно вывести 9

# %%
def compose_functions(s, k):
    result = k
    for i in s:
        result=i(result)
    return result

add_one = lambda x: x + 1
double = lambda x: x * 2
subtract_three = lambda x: x - 3
functions = [add_one, double, subtract_three]
print(compose_functions(functions, 5))
# Out:
# 9

# %% [markdown]
# # РАЗБОР ДОМАШНЕГО ЗАДАНИЯ 28

# %% [markdown]
# ### Задание 1
# Напишите программу, которая принимает список слов от пользователя и использует генераторное выражение (comprehension) для создания нового списка, содержащего только те слова, которые начинаются с гласной буквы. Затем программа должна использовать функцию map, чтобы преобразовать каждое слово в верхний регистр. В результате программа должна вывести новый список, содержащий только слова, начинающиеся с гласной буквы и записанные в верхнем регистре.

# %%
words = input("Введите список слов: ").split()
vowels = "euioaуеыаоэяию"
vowels = vowels + vowels.upper()
v_words = [x for x in words if x[0] in vowels]
v_words_upper = map(lambda x: x.upper(), v_words)
print(list(v_words_upper))
# Out:
# Введите список слов: едем Едем быстро
# ['ЕДЕМ', 'ЕДЕМ']

# %% [markdown]
# ### Задание 2
#
# Напишите программу, которая принимает список чисел от пользователя и использует функцию reduce из модуля functools, чтобы найти произведение всех чисел в списке. Затем программа должна использовать функцию itertools.accumulate для накопления произведений чисел в новом списке. В результате программа должна вывести список, содержащий накопленные произведения.

# %%
from functools import reduce
from itertools import  accumulate
from operator import mul

numbers = [int(x) for x in input("Введите список чисел: ").split()]
product_red = reduce(lambda x, y: x * y, numbers)
print(product_red)

product_acc = accumulate(numbers, mul)
print(list(product_acc))
# Out:
# Введите список чисел: 1 2 3 4 5
# 120
# [1, 2, 6, 24, 120]

# %% [markdown]
# ## Определим класс

# %% [markdown]
# Пустой класс

# %%
class Car:
    pass

# %% [markdown]
# Добавим атрибуты класса в пространстве имён класса

# %%
class Car:
    color = "Red"
    status_engine = False

Car.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'color': 'Red',
#               'status_engine': False,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %% [markdown]
# Создадим экземпляры класса

# %%
porshe = Car()
print(id(porshe))
print(porshe.color)
print(porshe.status_engine)
# Out:
# 136955301729488
# Red
# False

# %%
bmw = Car()
print(id(bmw))
print(bmw.color)
print(bmw.status_engine)
# Out:
# 136955082542096
# Red
# False

# %%
Car.color = 'blue'

# %%
Car.color
# Out:
# 'blue'

# %% [markdown]
# Создадим атрибуты экземпляра класса

# %%
Car.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'color': 'Red',
#               'status_engine': False,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None,
#               '__annotations__': {}})

# %%
bmw.brand = 'bmw'
print(bmw.brand)
print(bmw.__dict__)
# Out:
# bmw
# {'brand': 'bmw'}

# %%
porshe.brand
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-e1df9baa2632> in <cell line: 0>()
# ----> 1 porshe.brand
#
# AttributeError: 'Car' object has no attribute 'brand'

# %%
porshe.color = 'Green'

# %%
porshe.color
# Out:
# 'Green'

# %% [markdown]
# Добавим атрибут класса

# %%
print(Car.__dict__)
Car.max_speed = 240
print(Car.__dict__)
# Out:
# {'__module__': '__main__', 'color': 'blue', 'status_engine': False, '__dict__': <attribute '__dict__' of 'Car' objects>, '__weakref__': <attribute '__weakref__' of 'Car' objects>, '__doc__': None, '__annotations__': {}}
# {'__module__': '__main__', 'color': 'blue', 'status_engine': False, '__dict__': <attribute '__dict__' of 'Car' objects>, '__weakref__': <attribute '__weakref__' of 'Car' objects>, '__doc__': None, '__annotations__': {}, 'max_speed': 240}

# %%
print(porshe.max_speed)
print(porshe.__dict__)
print(bmw.max_speed)
print(bmw.__dict__)
# Out:
# 240
# {'color': 'Green'}
# 240
# {'brand': 'bmw'}

# %% [markdown]
# ### Методы класса

# %%
class Car:
    color = "Red"
    status_engine = False

    def engine_on():
        print("Двигатель заведён")

Car.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'color': 'Red',
#               'status_engine': False,
#               'engine_on': <function __main__.Car.engine_on()>,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
Car.engine_on()
Car.status_engine
# Out:
# Двигатель заведён
# False

# %%
porshe = Car()
print(porshe.__dict__)
dir(porshe)
# Out:
# {}
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'color',
#  'engine_on',
#  'status_engine']

# %%
porshe.engine_on()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-05caa4475f63> in <cell line: 0>()
# ----> 1 porshe.engine_on()
#
# TypeError: Car.engine_on() takes 0 positional arguments but 1 was given

# %%
class Car:
    color = "Red"
    status_engine = False

    def engine_on(self):
        print(self)
        print("Двигатель заведён у объекта под номером")
        print(id(self))

Car.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'color': 'Red',
#               'status_engine': False,
#               'engine_on': <function __main__.Car.engine_on(self)>,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
print(porshe)
# Out:
# <__main__.Car object at 0x7c8f1cd494d0>

# %%
porshe = Car()
print(id(porshe))
porshe.engine_on()
# Out:
# 136954105861328
# <__main__.Car object at 0x7c8f1cd494d0>
# Двигатель заведён у объекта под номером
# 136954105861328

# %%
porshe.status_engine
# Out:
# False

# %%
print(bmw)
# Out:
# <__main__.Car object at 0x7c8f1cd4b790>

# %%
bmw = Car()
print(id(bmw))
bmw.engine_on()
# Out:
# 136954105870224
# <__main__.Car object at 0x7c8f1cd4b790>
# Двигатель заведён у объекта под номером
# 136954105870224

# %% [markdown]
# Создадим сеттер и геттер

# %%
class Car:
    color = "Red"
    status_engine = False

    def engine_on(self):
        print("Двигатель заведён")
        self.status_engine = True

    def engine_off(self):
        print("Двигатель заглушен")
        self.status_engine = False

Car.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'color': 'Red',
#               'status_engine': False,
#               'engine_on': <function __main__.Car.engine_on(self)>,
#               'engine_off': <function __main__.Car.engine_off(self)>,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
porshe = Car()
print(porshe.status_engine)
porshe.engine_on()
print(porshe.status_engine)
# Out:
# False
# Двигатель заведён
# True

# %%
porshe.engine_off()
print(porshe.status_engine)
# Out:
# Двигатель заглушен
# False

# %%
Car.status_engine
# Out:
# False

# %% [markdown]
# Создадим возможность установки бренда

# %%
class Car:
    color = "Red"
    status_engine = False

    def engine_on(self):
        print("Двигатель заведён")
        self.status_engine = True

    def engine_off(self):
        print("Двигатель заглушен")
        self.status_engine = False

    def set_brand(self, brand):
        self.brand = brand

Car.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'color': 'Red',
#               'status_engine': False,
#               'engine_on': <function __main__.Car.engine_on(self)>,
#               'engine_off': <function __main__.Car.engine_off(self)>,
#               'set_brand': <function __main__.Car.set_brand(self, brand)>,
#               '__dict__': <attribute '__dict__' of 'Car' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Car' objects>,
#               '__doc__': None})

# %%
porshe = Car()
print(porshe.brand)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-014f71fbfb4a> in <cell line: 0>()
#       1 porshe = Car()
# ----> 2 print(porshe.brand)
#
# AttributeError: 'Car' object has no attribute 'brand'

# %%
porshe.set_brand("Porshe")
porshe.brand
# Out:
# 'Porshe'

# %%
class Центрефуга:
    количество_оборотов = 0

    def установить_количество_оборотов(self, обороты):
        if обороты > 5000:
            return "АЙ АЙ АЙ - опасно для жизни"
        elif обороты < 0:
            return "АЙ АЙ АЙ - меньше нуля нельяз"
        else:
            self.количество_оборотов = обороты

    def получить_текущее_количество_оборотов(self):
        return self.количество_оборотов

# %%
номер_1 = Центрефуга()
номер_1.количество_оборотов
# Out:
# 0

# %%
номер_1.количество_оборотов = 10000
номер_1.количество_оборотов
# Out:
# 10000

# %%
номер_1.установить_количество_оборотов(1000)
# номер_1.количество_оборотов = 1000

# %% [markdown]
# ### Практическое задание 2
#
# Создать класс Dog для представления собаки. Класс должен иметь атрибуты name (имя) и breed (порода), а также метод bark(), который выводит сообщение о том, что собака лает. Затем создать экземпляр класса Dog с заданным именем и породой и вызовите метод bark().
#
# Ожидаемый вывод:
#
# Шарик породы Дворняга лаял.

# %%
class Dog:  # классы с большой, функции с маленькой, переменные с маленькой
    def set_name(self, name):
        self.name = name

    def set_breed(self, breed):
        self.breed = breed

    def bark(self):
        print(f'{self.name} породы {self.breed} лаял')

# %%
sharik = Dog()
sharik.set_name('Bobik')
sharik.set_breed('Pudel')
sharik.bark()
